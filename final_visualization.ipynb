# %%
#dependencies
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
#get the cleaned table
movie_table=pd.read_csv("output/CleanMovieData.csv")
movie_table.head(3)
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
#
#   original_language  popularity release_date     revenue  runtime  \
# 0                en  150.437577   2009-12-10  2787965087    162.0
# 1                en  139.082615   2007-05-19   961000000    169.0
# 2                en  107.376788   2015-10-26   880674609    148.0
#
#                                       title  vote_average   ...    Music  \
# 0                                    Avatar           7.2   ...    False
# 1  Pirates of the Caribbean: At World's End           6.9   ...    False
# 2                                   Spectre           6.3   ...    False
#
#    Mystery  Romance  Science Fiction  Thriller  TV Movie    War  Western  \
# ...

# %%
#run function
# %run Functions1.ipynb
budgetVSruntime(movie_table)

# %%
#run function
# %run Functions1.ipynb
filmPERyear(movie_table)
# Out:
#         Film
# Decade
# 2000's  2107
# 2010's  1219
# 1990's   915
# 1980's   285
# 1970's   119
# 1960's    80
# 1950's    29
# 1940's    21
# 1930's    19
# 1920's     5
# 1910's     1

# %%
#run the function
# %run Functions1.ipynb
popularity_voteCount(movie_table)

# %%
# %run Functions2.ipynb
genre_count(movie_table)
# Out:
#               Genre  Counts  Percentage
# 0            Action    1154        9.49
# 1         Adventure     790        6.50
# 2         Animation     234        1.92
# 3            Comedy    1722       14.16
# 4             Crime     696        5.72
# 5       Documentary     109        0.90
# 6             Drama    2296       18.88
# 7            Family     513        4.22
# 8           Fantasy     424        3.49
# 9           Foreign      34        0.28
# 10          History     197        1.62
# 11           Horror     519        4.27
# 12            Music     185        1.52
# 13          Mystery     348        2.86
# 14          Romance     894        7.35
# 15  Science Fiction     535        4.40
# 16         Thriller    1274       10.48
# 17         TV Movie       8        0.07
# 18              War     144        1.18
# 19          Western      82        0.67

# %%
# %run Functions2.ipynb
revenue_decade(movie_table)
# Out:
#     Decade       budget       revenue  profitratio
# 0   1910's       385907       8394751        21.75
# 1   1920's     97194000      35008422         0.36
# 2   1930's     24351164     846101038        34.75
# 3   1940's     39232785     417958774        10.65
# 4   1950's     74981596     443342165         5.91
# 5   1960's    446566033    2409245720         5.40
# 6   1970's    916422794    7471821190         8.15
# 7   1980's   3724477523   19160580166         5.14
# 8   1990's  23977877510   68012714056         2.84
# 9   2000's  61350415636  164331219774         2.68
# 10  2010's  40621297228  128357122941         3.16

# %%
# %run Functions2.ipynb
profit_runtime(movie_table)
# Out:
#   Runtime Range       revenue        budget  profitratio  count
# 0         30-60  5.796450e+06  5.500000e+06         1.05      2
# 1         60-90  8.332761e+07  2.882380e+07         2.89    393
# 2        90-120  9.775888e+07  3.579256e+07         2.73   2006
# 3       120-150  1.823934e+08  5.637957e+07         3.24    684
# 4       150-180  2.879184e+08  7.498582e+07         3.84    109
# 5       180-360  1.854193e+08  3.992860e+07         4.64     35
# C:\Users\jcher\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#run the function
# %run Functions3.ipynb
genretrends(movie_table)
